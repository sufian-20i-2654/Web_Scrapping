# %% [markdown]
# # Name:Sufian Ahmed Shah
# # Roll No.:20i-2654
# # Assignment 6

# %% [markdown]
# # Instruction

# %% [markdown]
# 1. Don’t plagiarize, Plagiarism would lead to straight zero
# 2. Clearly mention your NAME and ROLL NO#.
# 3. Late submissions are not allowed. Start Early.

# %%
#import libraries
import requests
from lxml import etree
from bs4 import BeautifulSoup
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# # Question 1

# %% [markdown]
# Scrape 2 pages of the reviews for a single product listing using product URL.<br /> Note: Product must have more than 1 review page. The code must be generic and should work for every product listing URL, with proper checks in place.

# %%
website = 'https://www.daraz.pk/'
product=input('Enter the item you want to search:')
options=Options()
driver=webdriver.Chrome(ChromeDriverManager().install(),options=options)
driver.get(website)
driver.find_element_by_xpath('//*[@id="q"]').send_keys(product+Keys.RETURN)
driver.find_element_by_class_name('c1ZEkM').click()
try:
    driver.find_element_by_xpath('/html/body/div[4]/div/div[8]/div[1]/div[2]/div/div/div[3]/div[1]/div[1]/div[3]/div[1]').click()
except:
    rev=[]
rev=[]
for reviews in driver.find_element_by_class_name('mod-reviews').text:
    rev.append(reviews)
rev=''.join(rev)
rev=rev.split('\n')
rev
reviews=[]
driver.find_element_by_xpath('//*[@id="module_product_review"]/div/div[3]/div[2]/div/div/button[2]').click()
try:
    driver.find_element_by_xpath('/html/body/div[4]/div/div[8]/div[1]/div[2]/div/div/div[3]/div[1]/div[2]/div[3]/div[1]').click()
except:
    reviews=[]

time.sleep(10)

for i in driver.find_element_by_class_name('mod-reviews').text:
    reviews.append(i)
reviews=''.join(reviews)
reviews=reviews.split('\n')
# Out:
# Enter the item you want to search:mobile phones
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\Client Ahmed\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# <ipython-input-28-6bd197be42be>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install(),options=options)
# <ipython-input-28-6bd197be42be>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="q"]').send_keys(product+Keys.RETURN)
# <ipython-input-28-6bd197be42be>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_class_name('c1ZEkM').click()
# ...

# %%
names=[]
review=[]
counter=0
for i in rev:
    if i[0:2]=='by':
        if 'Verified Purchase' in i:
            names.append(i[3:-17])
        else:
            names.append(i[3:])
        counter=1
    else:
        if counter==1:
            counter=0
            review.append(i)
for n in reviews:
        if n[0:2]=='by':
            if 'Verified Purchase' in n:
                names.append(n[3:-17])
            else:
                names.append(n[3:])
            counter=1
        else:
            if counter==1:
                counter=0
                review.append(n)
df=pd.DataFrame({'Names':names,'Reviews':review})
df
# Out:
#           Names                                            Reviews
# 0  Ghazanfar M.  This is my second purchase great phone my fath...
# 1     hashir A.  satisfied although I  ordered a different colo...
# 2      Sobia J.  very satisfied with product as well as quick d...
# 3      Hafiz F.                  Awesome phone in this price range
# 4     zaryab A.                               Perfect. Recommended
# 5      Saqib A.       Storage Capacity:64GB, Color Family:Charcoal
# 6     Hassan K.  This is the first phone I bought from Daraz on...
# 7      Nasir J.  Received the nokia 3.4 dusk which is nicer the...
# 8         3***1  working very slow .too much hanging problems.c...
# 9         3***1      Amazing product. But battery drops frequently

# %% [markdown]
# # Question 2

# %% [markdown]
# Scrape 80 items for a keyword search e.g., 'mobile covers'<br/>Note: Must use "click()" function of webElement, URL changing for pages is not allowed. The code must be generic and should work for every keyword, with proper checks in place. Bonus for also scraping country and Daraz Mall availability.

# %%
website = 'https://www.daraz.pk/'
product=input('Enter the product:')
rev=[]
counter=0
options=Options()
driver=webdriver.Chrome(ChromeDriverManager().install(),options=options)
driver.get(website)
driver.find_element_by_xpath('//*[@id="q"]').send_keys(product+Keys.RETURN)
while counter<=80:
    for i in driver.find_element_by_class_name('c1z9Ut').text:
        rev.append(i)
        counter+=1
        if (counter==80):
            break
    time.sleep(5)
rev=''.join(rev)
rev=rev.split('\n')
rev

price=[]
name=[]
reviews=[]

counter1=0
counter2=0
counter3=0
for i in rev:
    if i[0:3]=='Rs.' and i[-1]!='%':
        price.append(i[3:])
        counter1=counter1+1
    elif i[0]=='(' and i[-1]==')':
        reviews.append(i[1:-1])
        counter2=counter2+1
    elif i!='Sort By:' and i!='Best Match' and i!='Installment available' and i[-1]!='%' and i[0:3]!='Rs.' and i!='Pakistan' and i!='China' and i!='View:' and i!='12345102':
        name.append(i)
        counter3=counter3+1
    else:
        continue
name1=[]
for i in range (2,len(name)):
    name1.append(name[i])

df=pd.DataFrame({'Names':name1,'Price':price})
df
# Out:
# Enter the product:mobile phones
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\Client Ahmed\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# <ipython-input-24-0c7c6e3a22f9>:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install(),options=options)
# <ipython-input-24-0c7c6e3a22f9>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="q"]').send_keys(product+Keys.RETURN)
# <ipython-input-24-0c7c6e3a22f9>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   for i in driver.find_element_by_class_name('c1z9Ut').text:
#                                                 Names     Price
# ...

# %% [markdown]
# # Question 3

# %% [markdown]
# Which Products are on Flash sale? Display Product name, Actual Price, Discounted Price, Discount Percentage, Rating, No. of Reviews, Top 3 reviews displayed.
#
# Display output must be like this. Products may vary.

# %%
#Run this cell to see output
pd.read_csv('sample.csv')

# %% [markdown]
# # Question 4

# %% [markdown]
# #### Submit .py file
